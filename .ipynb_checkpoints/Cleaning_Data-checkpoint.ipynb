# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread(r'C:\Users\Yogesh Sangtani\Desktop\CS\Img Classify\test_images_1\35.jpg')
img.shape
# Out:
# (650, 520, 3)

# %%
plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (650, 520)

# %%
gray
# Out:
# array([[223, 225, 228, ..., 250, 250, 250],
#        [221, 223, 226, ..., 250, 250, 250],
#        [221, 222, 225, ..., 249, 250, 250],
#        ...,
#        [237, 237, 237, ..., 193, 193, 193],
#        [237, 237, 237, ..., 192, 192, 191],
#        [237, 237, 237, ..., 192, 192, 191]], dtype=uint8)

# %%
plt.imshow(gray)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[222,  53, 196, 196]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (222, 53, 196, 196)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (196, 196, 3)

# %%
#Wavelet Transform
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images_1/35.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images_1/35.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./test_images_1/93.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images_1/93.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./image_dataset/"
path_to_cr_data = "./image_dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./image_dataset/Sara_Ali_Khan',
#  './image_dataset/Shah_Rukh_Khan',
#  './image_dataset/Tiger_Shroff',
#  './image_dataset/Yami_Gautam']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Sara_Ali_Khan
# Generating cropped images in folder:  ./image_dataset/cropped/Sara_Ali_Khan
# Shah_Rukh_Khan
# Generating cropped images in folder:  ./image_dataset/cropped/Shah_Rukh_Khan
# Tiger_Shroff
# Generating cropped images in folder:  ./image_dataset/cropped/Tiger_Shroff
# Yami_Gautam
# Generating cropped images in folder:  ./image_dataset/cropped/Yami_Gautam

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Sara_Ali_Khan': ['./image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan1.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan10.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan11.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan12.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan13.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan14.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan15.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan16.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan17.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan18.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan19.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan2.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan20.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan21.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan22.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan23.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan24.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan25.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan26.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan27.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan28.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan29.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan3.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan30.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan31.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan32.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan33.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan34.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan35.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan36.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan37.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan38.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan39.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan4.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan40.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan41.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan42.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan43.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan44.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan45.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan46.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan47.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan48.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan49.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan5.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan50.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan51.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan52.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan53.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan54.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan55.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan56.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan57.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan58.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan59.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan6.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan60.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan61.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan62.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan63.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan64.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan65.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan66.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan67.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan68.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan69.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan7.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan70.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan71.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan72.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan73.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan74.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan75.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan76.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan77.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan78.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan8.png',
#   './image_dataset/cropped/Sara_Ali_Khan\\Sara_Ali_Khan9.png'],
#  'Shah_Rukh_Khan': ['./image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan1.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan10.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan11.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan12.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan13.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan14.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan15.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan16.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan17.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan18.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan19.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan2.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan20.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan21.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan22.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan23.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan24.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan25.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan26.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan27.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan28.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan29.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan3.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan30.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan31.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan32.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan33.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan34.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan35.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan36.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan37.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan38.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan39.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan4.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan40.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan41.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan42.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan43.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan44.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan45.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan46.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan47.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan48.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan49.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan5.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan50.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan51.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan52.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan53.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan54.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan55.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan56.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan57.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan58.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan59.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan6.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan60.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan61.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan62.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan63.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan64.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan65.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan66.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan67.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan68.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan69.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan7.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan70.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan71.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan72.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan73.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan74.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan75.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan76.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan77.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan78.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan79.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan8.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan80.png',
#   './image_dataset/cropped/Shah_Rukh_Khan\\Shah_Rukh_Khan9.png'],
#  'Tiger_Shroff': ['./image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff1.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff10.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff11.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff12.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff13.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff14.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff15.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff16.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff17.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff18.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff19.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff2.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff20.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff21.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff22.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff23.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff24.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff25.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff26.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff27.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff28.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff29.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff3.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff30.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff31.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff32.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff33.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff34.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff35.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff36.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff37.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff38.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff39.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff4.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff40.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff41.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff42.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff43.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff44.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff45.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff46.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff47.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff48.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff49.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff5.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff50.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff51.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff52.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff53.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff54.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff55.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff56.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff57.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff58.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff59.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff6.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff60.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff61.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff62.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff63.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff64.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff65.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff66.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff67.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff68.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff69.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff7.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff70.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff71.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff72.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff73.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff74.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff75.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff76.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff77.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff78.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff8.png',
#   './image_dataset/cropped/Tiger_Shroff\\Tiger_Shroff9.png'],
#  'Yami_Gautam': ['./image_dataset/cropped/Yami_Gautam\\Yami_Gautam1.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam10.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam100.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam101.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam102.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam103.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam104.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam105.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam106.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam107.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam108.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam109.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam11.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam110.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam111.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam112.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam113.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam114.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam115.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam116.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam117.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam118.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam119.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam12.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam120.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam121.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam122.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam123.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam124.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam125.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam126.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam13.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam14.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam15.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam16.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam17.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam18.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam19.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam2.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam20.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam21.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam22.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam23.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam24.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam25.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam26.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam27.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam28.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam29.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam3.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam30.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam31.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam32.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam33.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam34.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam35.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam36.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam37.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam38.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam39.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam4.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam40.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam41.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam42.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam43.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam44.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam45.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam46.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam47.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam48.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam49.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam5.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam50.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam51.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam52.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam53.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam54.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam55.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam56.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam57.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam58.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam59.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam6.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam60.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam61.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam62.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam63.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam64.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam65.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam66.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam67.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam68.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam69.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam7.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam70.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam71.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam72.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam73.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam74.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam75.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam76.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam77.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam78.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam79.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam8.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam80.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam81.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam82.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam83.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam84.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam85.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam86.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam87.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam88.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam89.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam9.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam90.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam91.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam92.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam93.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam94.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam95.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam96.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam97.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam98.png',
#   './image_dataset/cropped/Yami_Gautam\\Yami_Gautam99.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Sara_Ali_Khan': 0, 'Shah_Rukh_Khan': 1, 'Tiger_Shroff': 2, 'Yami_Gautam': 3}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 36],
#        [ 79],
#        [ 68],
#        ...,
#        [253],
#        [252],
#        [  8]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (362, 4096)

# %%
#Model Training
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8021978021978022

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.52      0.65        23
#            1       0.78      0.74      0.76        19
#            2       0.81      0.96      0.88        23
#            3       0.78      0.96      0.86        26
#
#     accuracy                           0.80        91
#    macro avg       0.81      0.79      0.79        91
# weighted avg       0.81      0.80      0.79        91

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.785993
# 1        random_forest    0.623502
# 2  logistic_regression    0.763906
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8241758241758241

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6703296703296703

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8241758241758241

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[14,  2,  2,  5],
#        [ 2, 14,  3,  0],
#        [ 0,  0, 23,  0],
#        [ 2,  0,  0, 24]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Sara_Ali_Khan': 0, 'Shah_Rukh_Khan': 1, 'Tiger_Shroff': 2, 'Yami_Gautam': 3}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\yogesh sangtani\anaconda3\lib\site-packages (0.15.1)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
